# %% [markdown]
# <a href="https://colab.research.google.com/github/Lis193/math-UCE/blob/main/CLASE_5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **🖥Clase # 5**

# %% [markdown]
# # **📏Funciones Biyectivas y Compuestas**
# **¿Las funciones se relacionan con economía? 👀**
#
# Sí, las funciones se relacionan estrechamente con la economía de diversas maneras. La matemática, y en particular las funciones, son herramientas fundamentales para el análisis económico.
# Un ejemplo claro de dónde se utiliza las funcines es en un modelo económico.

# %% [markdown]
# # **✔ Elementos de una función**
# **Dominio:** El conjunto de todos los valores de entrada válidos para la función.
#
# **Codominio:** El conjunto de todos los valores de salida posibles de la función.
#
# **Imagen:** El subconjunto del codominio que contiene todos los valores de salida que realmente toma la función.
#
# **Regla de correspondencia:** La regla que define cómo se transforma un valor de entrada en un valor de salida.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # **⚙ Gráfica de una Función**
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## 🎲 Imagen y Preimagen de una Función
# Cuando hablamos de funciones, es crucial entender los conceptos de imagen y preimagen:
#
# ### ♟ Preimagen
# La preimagen de un conjunto en \(B\) es el conjunto de todos los elementos en \(A\) que se mapean a ese conjunto específico en \(B\) bajo la función \(f\). La preimagen de un elemento \(y\) en \(B\) se denota como \(f^{-1}(y)\). Este conjunto de valores se denomina Dominio de la función.
#
# ### 📌 Imagen
# La imagen de un conjunto \(A\) bajo una función \(f\) es el conjunto de todos los valores que \(f(x)\) puede tomar cuando \(x\) varía en \(A\). Matemáticamente, se denota como \(f(A)\). Este conjunto de valores se conoce como el Rango o Recorrido de la función.

# %% [markdown]
# #⭕ Gráfica de Preimagen e Imagen
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # **♦ Función Sobreyectiva, Biyectiva, Inyectiva, Inversa y Compuesta**
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # **📍 Función Compuesta**
# Una función compuesta es una nueva función que se obtiene al combinar dos o más funciones existentes. Se forma aplicando una función a la salida de otra función. La función compuesta se representa con el símbolo ∘, donde f ∘ g denota la función compuesta formada por las funciones f y g.
#
# **Notación**
#
# La notación para una función compuesta f ∘ g significa que primero se aplica la función g a la entrada, y luego se aplica la función f al resultado de g. Matemáticamente, se expresa como:
#
# $( f(x) $) y luego $( g $) a $( f(x) $).
#
#  ![image.png](data:image/png;base64,...)

# %% [markdown]
# **🧩 Ejemplo de función compuesta en Python:**

# %%
def funcion_interna(x):
  return x ** 2

def funcion_externa(y):
  return 2 * y + 1

def funcion_compuesta(x):
  return funcion_externa(funcion_interna(x))

# Ejemplo de uso
resultado = funcion_compuesta(3)
print(resultado)  # Salida: 13
# Out:
# 19

# %% [markdown]
# # **🔎 Grafica de una Función Compuesta**
# ![image.png](data:image/png;base64,...)
