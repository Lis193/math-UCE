# %% [markdown]
# <a href="https://colab.research.google.com/github/Lis193/math-UCE/blob/main/CLASE_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 👀 **CLASE # 1**
#
# ##  ⭕**Elementos de Lógica y Conjuntos**
# Vamos a conocer los conceptos básicos de lógica y teoría de conjuntos, que son fundamentales para las matemáticas y, en particular, para la economía.
#
# **Lógica Proposicional**
#
# Es una rama fundamental de la lógica que se enfoca en el análisis de la validez de argumentos y proposiciones.
#
# **Definición de Proposición**
#
# Una proposición es una afirmación que puede ser verdadera o falsa, pero no ambas.Ejemplo: El sol es una estrella.
#
# **Operadores Lógicos**
#
# Son como las piezas maestras que nos permiten combinar proposiciones simples y construir enunciados complejos con significados precisos. Al igual que los bloques de construcción, estos operadores nos dan la flexibilidad de crear estructuras lógicas sólidas y analizar argumentos con rigor.
#
# **Los operadores lógicos principales son:**
#
# **Negación**(¬)
#
# **Conjunción (y) (∧)** Se hace verdadera si todos son V
#
# **Disyunción (O)(∨)** Se hace verdadera si al menos uno es V
#
# **Implicación o Etonces** (→)
#
# **Doble implicación o Sí y solo sí** (↔)
#
# # **Ejemplos en Python con los Operadores Lógicos:**
#
# Para empezar a realizra progración en python sobre los operadores lógicos debemos tener en cuenta algunas definciones, que son la siguientes:
#
# **1. ✏ Comparaciones básicas:**
# Las comparaciones son la base de la lógica computacional. En Python, podemos utilizar operadores de comparación para evaluar la relación entre dos valores:
#
# **==: Igualdad** (comprueba si dos valores son exactamente iguales)
#
# **!=: Desigualdad** (comprueba si dos valores no son exactamente iguales)
#
# **">": Mayor que** (comprueba si un valor es mayor que otro)
#
# **<: Menor que** (comprueba si un valor es menor que otro)
#
# **">=:" Mayor o igual que** (comprueba si un valor es mayor o igual que otro)
#
# **<=: Menor o igual que** (comprueba si un valor es menor o igual que otro)
#
# **Ejemplo en Python**

# %%
edad = 18
es_mayor_de_edad = edad >= 18

print(f"¿Es mayor de edad? {es_mayor_de_edad}")  # Salida: ¿Es mayor de edad? True
# Out:
# ¿Es mayor de edad? True

# %% [markdown]
# **2. ✏ Operadores lógicos binarios:**
#
# Los operadores lógicos binarios nos permiten combinar dos valores booleanos para obtener un nuevo valor booleano. Entre los más comunes encontramos:
#
# **and:** Conjunción (ambos valores deben ser True para que la expresión sea True)
#
# **or:** Disyunción (al menos uno de los valores debe ser True para que la expresión sea True)
#
# **not:** Negación (invierte el valor del booleano original)
#
# **Ejemplo en Python**

# %%
esta_lloviendo = True
hace_sol = False

puede_ir_a_la_playa = not esta_lloviendo and hace_sol

print(f"¿Puede ir a la playa? {puede_ir_a_la_playa}")  # Salida: ¿Puede ir a la playa? True
# Out:
# ¿Puede ir a la playa? False

# %% [markdown]
# **3. ✏ Operadores lógicos anidados:**
#
# Los operadores lógicos pueden anidarse para crear expresiones aún más complejas. Las reglas de precedencia determinan el orden de evaluación:
#
# **not** se evalúa primero
#
# **and y or** se evalúan de izquierda a derecha
#
# **Ejemplo en Python**

# %%
esta_lloviendo = True
hace_sol = False
tiene_sombrilla = True

puede_ir_al_parque = (not esta_lloviendo or hace_sol) and tiene_sombrilla

print(f"¿Puede ir al parque? {puede_ir_al_parque}")  # Salida: ¿Puede ir al parque? True
# Out:
# ¿Puede ir al parque? False

# %% [markdown]
# **4. ✏ Funciones lógicas:**
#
# Python ofrece funciones lógicas integradas para realizar operaciones más específicas:
#
# **any():** Evalúa si al menos un elemento en un iterable es True
#
# **all():** Evalúa si todos los elementos en un iterable son True
#
# **Ejemplo en Python**

# %%
frutas = ["manzana", "naranja", "pera"]

hay_manzana = any(fruta == "manzana" for fruta in frutas)
son_todas_frutas = all(fruta in ["manzana", "naranja", "pera"] for fruta in frutas)

print(f"¿Hay manzana en la lista? {hay_manzana}")  # Salida: ¿Hay manzana en la lista? True
print(f"¿Son todas las frutas manzana, naranja o pera? {son_todas_frutas}")  # Salida: ¿Son todas las frutas manzana, naranja o pera? True
# Out:
# ¿Hay manzana en la lista? True
# ¿Son todas las frutas manzana, naranja o pera? True

# %% [markdown]
# # 🔴 **Cuantificadores**
# Son palabras o símbolos que nos permiten expresar proposiciones que abarcan todos o algunos elementos de un conjunto.
#
# **Tipos de cuantificadores:**
#
# Existen dos tipos principales de cuantificadores:
#
# **Cuantificador universal (∀):** Representado por "para todo", "todo" o "cada", el cuantificador universal indica que la proposición es verdadera para todos los elementos del conjunto sin excepción. Por ejemplo: "∀x ∈ ℝ, x^2 ≥ 0" (para todo número real x, x al cuadrado es mayor o igual que 0).
#
#  **Cuantificador existencial (∃)**: Representado por "existe", "hay" o "alguno", el cuantificador existencial indica que la proposición es verdadera para al menos un elemento del conjunto. Por ejemplo: "∃x ∈ ℤ, x^2 = 2" (existe un número entero x tal que x al cuadrado es igual a 2).
#
# **Negación de proposiciones cuantificadas:**
#
# La negación de una proposición cuantificada se realiza invirtiendo el cuantificador y negando el predicado.
#
# * La negación de "∀x ∈ ℝ, x^2 ≥ 0" es "∃x ∈ ℝ, x^2 < 0" (existe un número real x tal que x al cuadrado es menor que 0).
#
# * La negación de "∃x ∈ ℤ, x^2 = 2" es "∀x ∈ ℤ, x^2 ≠ 2" (para todo número entero x, x al cuadrado es diferente de 2).
#
# **Ejemplos en Python**
#
# **1. Cuantificador universal (∀):**
#
# Para simular el cuantificador universal "∀x ∈ D, P(x)", donde "D" es el conjunto de discurso y "P(x)" es el predicado, podemos utilizar un bucle **FOR** que recorre cada elemento en "D" y verifica si el predicado "P(x)" es verdadero para cada uno. Si el predicado es falso para al menos un elemento, la proposición completa se considera falsa. En caso contrario, si el predicado es verdadero para todos los elementos, la proposición se considera verdadera

# %%
def es_par(x):
  return x % 2 == 0

def todos_pares(conjunto):
  for numero in conjunto:
    if not es_par(numero):
      return False
  return True

conjunto1 = {2, 4, 6, 8}
conjunto2 = {1, 3, 5}

print(todos_pares(conjunto1))  # Salida: True
print(todos_pares(conjunto2))  # Salida: False
# Out:
# True
# False

# %% [markdown]
# **2. Cuantificador existencial (∃):**
#
# Para simular el cuantificador existencial "∃x ∈ D, P(x)", podemos utilizar un bucle FOR que recorre cada elemento en "D" y verifica si el predicado "P(x)" es verdadero para al menos un elemento. Si encontramos un elemento para el cual el predicado es verdadero, la proposición completa se considera verdadera. En caso contrario, si el predicado es falso para todos los elementos, la proposición se considera falsa.

# %%
def es_primo(x):
  if x <= 1:
    return False
  for i in range(2, int(x**0.5) + 1):
    if x % i == 0:
      return False
  return True

def existe_primo(conjunto):
  for numero in conjunto:
    if es_primo(numero):
      return True
  return False

conjunto1 = {2, 3, 4, 5}
conjunto2 = {1, 6, 8, 9}

print(existe_primo(conjunto1))  # Salida: True
print(existe_primo(conjunto2))  # Salida: False
# Out:
# True
# False

# %% [markdown]
# # Tablas de Verdad ✔ ❌
# Será util para comprender el tema que estamos y tendremos una ayuda para ver como funciona tanto en las matematicas como en python# Nueva sección
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # 🔻**Teoría de Conjuntos**
#  Es una rama fundamental de las matemáticas y la lógica, se encarga de estudiar los conjuntos, agrupaciones abstractas de objetos que comparten alguna característica en común. A través de un lenguaje formal y riguroso, esta teoría nos permite analizar las propiedades de los conjuntos, las relaciones entre ellos y las operaciones que podemos realizar sobre ellos.
#
# **Definición de Conjunto**
#
# Un conjunto es una colección de elementos distintos. Los elementos pueden ser números, letras, u otros objetos.
#
# **Notación**:
#
# Un conjunto se denota con llaves: {a, b, c}
#
# Conjunto vacío: {}
#
# **Operaciones con Conjuntos**
#
# Unión (A ∪ B)
#
# Intersección (A ∩ B)
#
# Diferencia (A - B)
#
# Complemento (A^c)
#
# **Ejemplo en Python**

# %%
conjunto_A = {1, 2, 3}
conjunto_B = {3, 4, 5}

conjunto_union = conjunto_A | conjunto_B
print(conjunto_union)  # Salida: {1, 2, 3, 4, 5}
# Out:
# {1, 2, 3, 4, 5}

# %%
conjunto_A = {1, 2, 3}
conjunto_B = {3, 4, 5}

conjunto_interseccion = conjunto_A & conjunto_B
print(conjunto_interseccion)  # Salida: {3}
# Out:
# {3}

# %%
conjunto_A = {1, 2, 3}
conjunto_B = {3, 4, 5}

conjunto_diferencia = conjunto_A - conjunto_B
print(conjunto_diferencia)  # Salida: {1, 2}
# Out:
# {1, 2}

# %% [markdown]
# # 📕 **ACTIVIAD REALIZADA EN EL QUIZIZZ**
# ![image.png](data:image/png;base64,...)
