# %% [markdown]
# <a href="https://colab.research.google.com/github/Lis193/math-UCE/blob/main/CLASE_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **🧩CLASE N# 2**

# %% [markdown]
# # **♦ Alogaritmos**
#
# La piedra angular de la computación y la resolución de problemas
#
# *  Los algoritmos se erigen como herramientas poderosas para transformar datos en información útil y resolver problemas de manera eficiente. Son secuencias de instrucciones paso a paso, cuidadosamente definidas, que guían a una computadora o a una persona a través de un proceso para alcanzar un objetivo específico.
#
# 🔎**¿Qué hace que un algoritmo sea efectivo?**
#
# Un buen algoritmo debe cumplir con ciertas características:
#
# **Precisión:** Debe producir el resultado correcto para el problema que se está resolviendo.
#
# **Claridad:** Debe ser fácil de entender y seguir, tanto para humanos como para computadoras.
#
# **Eficiencia:** Debe utilizar la menor cantidad de recursos (tiempo, memoria, etc.) posible para completar la tarea.
#
# **Generalidad:** Debe ser adaptable a diferentes casos y situaciones dentro del problema que se está resolviendo.
#
# **Modularidad:** Debe estar compuesto por partes más pequeñas (subalgoritmos) que se pueden reutilizar y combinar de diferentes maneras.
#
# 📍**Tipos de algoritmos:**
#
# Existen diversos tipos de algoritmos, cada uno con sus propias características y aplicaciones:
#
# **Algoritmos de búsqueda:** Encuentran un elemento específico dentro de un conjunto de datos.
#
# **Algoritmos de ordenamiento:** Organizan un conjunto de datos en un orden determinado.
#
# **Algoritmos de recorrido:** Atraviesan y procesan todos los elementos de una estructura de datos.
#
# **Algoritmos recursivos:** Se definen a sí mismos en términos de casos más pequeños del mismo problema.
#
# **Algoritmos dinámicos:** Optimizan la solución de un problema mediante la reutilización de subcalculos.
#
# 📝**¿Dónde se utilizan los algoritmos?**
#
# Los algoritmos están presentes en casi todas las áreas de la informática y las matemáticas:
#
# **Sistemas operativos:** Gestionan los recursos del computador y ejecutan programas.
#
# **Compiladores:** Traducen código fuente en lenguaje de programación a lenguaje de máquina que la computadora puede entender.
#
# **Bases de datos:** Almacenan, organizan y recuperan información de manera eficiente.
#
# **Gráficos:** Crean imágenes y visualizaciones en computadoras y dispositivos móviles.

# %% [markdown]
# **💡EJEMPLO DE ALGORITMO**
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# #  **💻 Algoritmo de Programación**
# Son secuencias lógicas y ordenadas de pasos que le indican a una computadora qué hacer para resolver un problema específico.
#
# **🤷‍♀️¿Cómo funciona un algoritmo de programación?**
#
# Imagina que quieres crear un programa que calcule la suma de dos números. Un algoritmo para esta tarea podría ser:
#
# * Obtener los dos números del usuario.
# * Almacenar los números en variables.
# * Sumar los valores de las variables.
# * Mostrar el resultado de la suma al usuario.
#
# Este algoritmo se descompone en pasos más pequeños y específicos que la computadora puede comprender y ejecutar uno a la vez. Cada paso implica una operación o decisión que acerca al programa al objetivo final.
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # **✔ Cómo se estructura un algoritmo**
# La estructura para una buena creaciión de alogaritmo es:
# 1. **Inicio**
# 2. **Leer** el año de nacimiento
# 3.**Leer** el año actual
# 4.**Restar** el año actual menos el año d enacimiento
# 5. **Escribir** "la edad de la persona"
# 6. **Fin**
#
# ## **✔Elementos del diagrama de Flujo**
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # **💡 Estructura de Entrada, Proceso y Salida (EPS)**
# + Facilita la
# interacción eficiente de datos entre el
# usuario y el sistema computacional y el
# procesamiento de datos.
# + En la Salida se utiliza texto para añadir
# claridad y contexto a los datos de
# salida, facilitando la comprensión de
# los resultados por parte de los
# usuarios.
# # **✏Ejemplo de la Estructura EPS**
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # **Algoritmo del cálculo del área de un cuadrado ⬛**
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # **🎉Ejemplo en PyThon**

# %%
def ordenamiento_burbuja(lista):
  n = len(lista)
  for i in range(n):
    for j in range(0, n - i - 1):
      if lista[j] > lista[j + 1]:
        lista[j], lista[j + 1] = lista[j + 1], lista[j]

lista_desordenada = [5, 2, 4, 1, 3]
print(f"Lista desordenada: {lista_desordenada}")
ordenamiento_burbuja(lista_desordenada)
print(f"Lista ordenada: {lista_desordenada}")
# Out:
# Lista desordenada: [5, 2, 4, 1, 3]
# Lista ordenada: [1, 2, 3, 4, 5]

# %% [markdown]
# # **🤠 ¿Cómo Localizar Rápidamente un Número en una Lista Extensa?**
# Se lo puede haer medinate las siguientes búsquedas:
#
# **Búsqueda Lineal**
#
# • La búsqueda lineal implica revisar cada
# elemento secuencialmente hasta encontrar el
# objetivo. Este método es simple pero puede
# ser ineficiente en listas grandes.
#
# • El número máximo de pasos para encontrar un
# número sería n = 100.
#
#  **Ejmeplo en Python**

# %%
def buscar_lineal(lista, elemento):
  """
  Busca un elemento dentro de una lista utilizando búsqueda lineal.

  Args:
    lista: Lista de elementos a buscar.
    elemento: Elemento a buscar dentro de la lista.

  Returns:
    bool: True si el elemento se encuentra en la lista, False en caso contrario.
  """
  for i in range(len(lista)):
    if lista[i] == elemento:
      return True
  return False

# Ejemplo de uso
lista_nombres = ["Juan", "María", "Pedro", "Ana", "Carlos"]
elemento_a_buscar = "Ana"

resultado_busqueda = buscar_lineal(lista_nombres, elemento_a_buscar)

if resultado_busqueda:
  print(f"El elemento {elemento_a_buscar} SI se encuentra en la lista.")
else:
  print(f"El elemento {elemento_a_buscar} NO se encuentra en la lista.")
# Out:
# El elemento Ana SI se encuentra en la lista.

# %% [markdown]
# **Búsqueda Binaria**
#
# • La búsqueda binaria divide el conjunto de
# datos a la mitad en cada paso, lo que reduce
# significativamente el número de
# comparaciones necesarias, especialmente en
# conjuntos grandes.
#
# • El número máximo de pasos es
# aproximadamente log2 n . En este caso sería:
# log2 100 = 6.64 que se aproxima a 7.
#
# **Ejemplo en Python**

# %%
def busqueda_binaria(lista, elemento):
  """
  Busca un elemento en una lista ordenada utilizando búsqueda binaria.

  Args:
    lista: Lista ordenada de elementos.
    elemento: Elemento a buscar en la lista.

  Returns:
    int: Índice del elemento en la lista si se encuentra, -1 si no se encuentra.
  """
  izquierda = 0
  derecha = len(lista) - 1

  while izquierda <= derecha:
    mitad = (izquierda + derecha) // 2
    dato_mitad = lista[mitad]

    if dato_mitad == elemento:
      return mitad
    elif dato_mitad < elemento:
      izquierda = mitad + 1
    else:
      derecha = mitad - 1

  return -1

# Ejemplo de uso
lista_ordenada = [3, 8, 15, 22, 37, 49, 56, 62]
elemento_a_buscar = 37

indice = busqueda_binaria(lista_ordenada, elemento_a_buscar)

if indice != -1:
  print(f"El elemento {elemento_a_buscar} se encuentra en la posición {indice} de la lista.")
else:
  print(f"El elemento {elemento_a_buscar} NO se encuentra en la lista.")
# Out:
# El elemento 37 se encuentra en la posición 4 de la lista.

# %% [markdown]
# # **🎈 Sistemas Númericos**
# Es un conjunto de símbolos y reglas que se utilizan para representar y manipular cantidades. Estos símbolos, que pueden ser números, letras o incluso imágenes, se combinan de acuerdo a las reglas del sistema para formar números más grandes o más pequeños.
#
# **Ejemplos de conversión entre sistemas numéricos:**
#
# Convertir un número de un sistema numérico a otro implica comprender las reglas y características de cada sistema. Por ejemplo:
#
# **Convertir de decimal a binario:** Se divide el número decimal por 2 repetidamente, anotando el residuo en cada paso. Los residuos, en orden inverso, representan el número binario.
#
# **Convertir de binario a decimal:** Se multiplica cada dígito binario por su correspondiente potencia de 2 (2^0, 2^1, etc.) y se suman los resultados.
#
# **Ejemplo en Python**

# %% [markdown]
# **Conversión de binario a decimal:**
#
# Este ejemplo convierte un número binario a su representación decimal utilizando el **módulo math y la función int():**

# %%
def convertir_binario_a_decimal(numero_binario):
  """
  Convierte un número binario a su representación decimal.

  Args:
    numero_binario: El número binario a convertir (como cadena).

  Returns:
    int: El valor decimal del número binario.
  """
  return int(numero_binario, 2)

numero_binario = input("Ingrese un número binario: ")
resultado_decimal = convertir_binario_a_decimal(numero_binario)
print(f"El número binario {numero_binario} en decimal es: {resultado_decimal}")
# Out:
# Ingrese un número binario: 00110011
# El número binario 00110011 en decimal es: 51
