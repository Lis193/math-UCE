# %% [markdown]
# <a href="https://colab.research.google.com/github/Lis193/math-UCE/blob/main/CLASE_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **¿Cómo funciona un programa de computadora? 🖥️**
#
# Un programa es el alma de una computadora. Es lo que transforma una colección de componentes electrónicos (hardware) en una herramienta increíblemente útil y poderosa.
#
# ### La naturaleza de las computadoras 📌
# - Solo pueden ejecutar operaciones muy básicas, como sumar, restar, multiplicar y dividir
# - No tienen una comprensión inherente de conceptos abstractos o complejos
# - Su poder radica en su capacidad para ejecutar estas operaciones simples a una velocidad increíblemente rápida y repetirlas tantas veces como sea necesario
#
# **Lenguaje Natural: LLM** -> es un programa, de grandes modelos de lenguaje (Predice parráfos o ensayos).
#
# **Lenguaje de Programación:** Se debe poner palabras claves para que el lenguaje de programación entienda.
#
# + Las palabras claves deben estar escritas correctamente para que el programa ejecute.
#
# En el lenguaje de programación hay dos tipos:
#
# + Lenguaje de máquina
# + Lenguaje de alto nivel o de programación -> Comando
#
# Existe 2 formas para transformar un lenguaje de alto nivel a un lenguaje de maquina:
#
#  + Concepto de copilación: Copila las instrucciones que nosotros le damos.
#  + Concepto de Interpretación: Traduce las instrucciones al lenguaje de máquina

# %% [markdown]
# # **🧩 Lenguaje de Compliación:**
# El programa se ejecuta directamente, y si funciona dara un resultado.
# # **📝 Lenguaje Interprete:**
# Más fácil de aprender ya que nos guían para que funcione el programa o en caso que salga un error.
#
# | Ventajas | Desventajas |
# |---------------------|---------------------------|
# | Lenguaje de Compilación, tiene la ejecución del código más rapido.| Lenguaje de Compilación es un proceso que consume tiempo. |
# | Lenguaje de Interpretación, se ejecuta el código tan pronto que lo complete|Lenguaje de Interpretación, se debe tener un interprete para ejecutar el código y es más lento. |
# |

# %% [markdown]
# # **🔑 Python**
# ¿Qué es Python? 🤔
# Python fue creado por Guido van Rossum. Python es un lenguaje de programación de alto nivel, interpretado, orientado a objetos y de uso generalizado con semántica dinámica, que se utiliza para la programación de propósito general. 💻
#
# ![image.png](data:image/png;base64,...)
#
# El nombre del lenguaje de programación Python proviene de una vieja serie de comedia de la BBC llamada Monty Python's Flying Circus. 🎭🎪
#
# **¿Por qué aprender Python? 🚀**
#
# Python es un lenguaje de programación versátil y poderoso que tiene muchas ventajas:
#
# 📚 Es fácil de aprender y leer, lo que lo hace perfecto para principiantes.
#
# 🧩 Tiene una amplia gama de aplicaciones, desde desarrollo web hasta inteligencia artificial.
#
# 🌐 Es de código abierto y tiene una gran comunidad de desarrolladores que contribuyen con bibliotecas y herramientas.
#
# 💼 Es muy demandado en el mercado laboral, con muchas empresas buscando programadores de Python.

# %% [markdown]
# # **💻 Fundamentos de Python**
# Python es un lenguaje versátil, utilizado en diversas industrias y para múltiples aplicaciones, desde desarrollo web hasta ciencia de datos.
# + En este programa encontramos un SCRIPT -> ( Hoja donde se escribe nuestros programas).
# + Python es un lenguaje de alto nivel, es orientado a obejtos y es de proposito general (diferentes usos).

# %% [markdown]
# # **Ejemplos de scripts en Python ✏**
# **💡 Script para extraer datos de una página web:**
#
# Este script te permite extraer información específica de una página web, como precios, noticias o estadísticas, y almacenarla en un formato estructurado para su posterior análisis.

# %%
import requests
from bs4 import BeautifulSoup

def extraer_datos_web(url, selector_css, atributo):
  """
  Extrae datos de una página web utilizando BeautifulSoup.

  Args:
    url: La URL de la página web.
    selector_css: El selector CSS para identificar los elementos que contienen los datos.
    atributo: El atributo del elemento HTML que contiene el dato específico.
  """
  response = requests.get(url)
  soup = BeautifulSoup(response.content, 'html.parser')

  datos = []
  for elemento in soup.select(selector_css):
    dato = elemento.get(atributo)
    if dato:
      datos.append

# %% [markdown]
# # **📋 Sistemas Númericos**
#
# Los sistemas numéricos son conjuntos de símbolos y reglas que utilizamos para representar y manipular cantidades.
#
# Cada sistema numérico tiene sus propias características, como:
#
# Base: La unidad fundamental a partir de la cual se construyen los demás números. Por ejemplo, el sistema decimal tiene una base de 10, mientras que el sistema binario tiene una base de 2.
#
# Símbolos: Los elementos que representan las unidades básicas del sistema. En el sistema decimal, los símbolos son los dígitos del 0 al 9.
#
# Valor posicional: En algunos sistemas, como el decimal, el valor de un símbolo depende de la posición que ocupa dentro del número. Por ejemplo, en el número 123, el 1 vale 100, el 2 vale 20 y el 3 vale 3.
#
# Reglas de operación: Las normas que definen cómo realizar operaciones aritméticas como la suma, resta, multiplicación y división.
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # **♦ Ejemplo en Python**
# Cálculos en sistemas numéricos:

# %%
def sumar_binarios(binario1, binario2):
  """
  Suma dos números binarios.

  Args:
    binario1: El primer número binario como una cadena de caracteres.
    binario2: El segundo número binario como una cadena de caracteres.

  Returns:
    str: La suma de los dos números binarios como una cadena de caracteres.
  """
  resultado = ""
  carry = 0
  i = len(binario1) - 1
  j = len(binario2) - 1
  while i >= 0 or j >= 0:
    suma_digitos = 0
    if i >= 0:
      suma_digitos += int(binario1[i])
    if j >= 0:
      suma_digitos += int(binario2[j])
    suma_digitos += carry

    if suma_digitos >= 2:
      digito = suma_digitos % 2
      carry = 1
    else:
      digito = suma_digitos
      carry = 0

    resultado = str(digito) + resultado
    i -= 1
    j -= 1
  if carry:
    resultado = "1" + resultado
  return resultado

numero_binario1 = input("Ingrese el primer número binario: ")
numero_binario2 = input("Ingrese el segundo número binario: ")
suma = sumar_binarios(numero_binario1, numero_binario2)
print(f"La suma de {numero_binario1} y {numero_binario2} es: {suma}")
# Out:
# Ingrese el primer número binario: 1000
# Ingrese el segundo número binario: 11001
# La suma de 1000 y 11001 es: 100001

# %% [markdown]
# # **♟ Conceptos básicos de Cardinalidad**
# Conjunto: Una colección de elementos bien definidos y distinguibles entre sí. Los elementos de un conjunto pueden ser números, objetos, ideas o cualquier otra entidad.
#
# **Elemento:** Cada uno de los componentes que forman parte de un conjunto.
#
# **Cardinalidad:** El número de elementos que contiene un conjunto. Se representa con el símbolo # o con la letra n.
#
# **🕹Tipos de cardinalidad:**
#
# **Cardinalidad finita:** Un conjunto finito es aquel que tiene un número determinado y contable de elementos. Se puede contar cada elemento del conjunto, uno por uno.
#
# Ejemplo: Un conjunto que contiene las letras del alfabeto inglés tiene una cardinalidad finita de 26 elementos.
#
# **Cardinalidad infinita:** Un conjunto infinito es aquel que tiene un número incontable de elementos. No se puede contar cada elemento del conjunto, uno por uno.
#
# Ejemplo: El conjunto de todos los números naturales (1, 2, 3, ...) es un conjunto infinito.
#
# **🔎 Propiedades de la cardinalidad:**
#
# **Cardinalidad del conjunto vacío:** El conjunto vacío, que no contiene ningún elemento, tiene una cardinalidad de 0.
# Cardinalidad de un conjunto unitario: Un conjunto unitario, que contiene un solo elemento, tiene una cardinalidad de 1.
#
# **Cardinalidad de un subconjunto:** La cardinalidad de un subconjunto de un conjunto nunca puede ser mayor que la cardinalidad del conjunto original.
#
# **Cardinalidad de la unión de dos conjuntos:** La cardinalidad de la unión de dos conjuntos disjuntos (que no comparten elementos comunes) es igual a la suma de las cardinalidades de los conjuntos individuales.

# %% [markdown]
# # **😎 Ejemplo en Python**

# %%
# Ejemplo 1: Cardinalidad de una lista usando un bucle for
conjunto_animales = ["perro", "gato", "conejo"]
cardinalidad = 0

for animal in conjunto_animales:
  cardinalidad += 1

print(f"La cardinalidad del conjunto de animales es: {cardinalidad}")  # Salida: 3

# Ejemplo 2: Cardinalidad de un conjunto usando un bucle for
conjunto_letras = {"a", "b", "c", "d"}
cardinalidad = 0

for letra in conjunto_letras:
  cardinalidad += 1

print(f"La cardinalidad del conjunto de letras es: {cardinalidad}")  # Salida: 4
# Out:
# La cardinalidad del conjunto de animales es: 3
# La cardinalidad del conjunto de letras es: 4

# %% [markdown]
# # **Producto Cratesiano 📊**
# El producto cartesiano de dos conjuntos A y B, representado como A x B, se define como el conjunto que contiene todos los pares ordenados posibles, donde el primer elemento pertenece a A y el segundo elemento pertenece a B.
# El producto cartesiano se puede representar de diversas maneras:
#
# **Notación por pares ordenados**: {(a, b) | a ∈ A, b ∈ B}
#
# Notación matricial: [Elemento 1 de A, Elemento 2 de A, ..., Elemento n de A] x [Elemento 1 de B, Elemento 2 de B, ..., Elemento m de B]
#
# **⚖ Propiedades del producto cartesiano:**
#
# **Propiedad conmutativa:** El orden de los conjuntos en el producto cartesiano no altera el resultado. Es decir, A x B = B x A.
#
# **Propiedad asociativa:** El producto cartesiano de más de dos conjuntos se puede asociar de cualquier manera sin afectar el resultado. Es decir, (A x B) x C = A x (B x C).
#
# **Propiedad de conjuntos vacíos:** El producto cartesiano de un conjunto con el conjunto vacío es el conjunto vacío. Es decir, A x ∅ = ∅ y ∅ x B = ∅.

# %% [markdown]
# # **📏 Gráfica del Producto Cartesiano**
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # **⭕ Ejemplos del Producto Cartesiano en Python**

# %%
import itertools

# Ejemplo 1: Producto cartesiano de dos listas
conjunto_colores = ["rojo", "verde", "azul"]
conjunto_formas = ["cuadrado", "círculo", "triángulo"]

producto_cartesiano = list(itertools.product(conjunto_colores, conjunto_formas))
print(producto_cartesiano)  # Salida: [('rojo', 'cuadrado'), ('rojo', 'círculo'), ('rojo', 'triángulo'), ('verde', 'cuadrado'), ..., ('azul', 'triángulo')]

# Ejemplo 2: Producto cartesiano de un conjunto y un rango
conjunto_letras = "abc"
rango_numeros = range(1, 4)

producto_cartesiano = list(itertools.product(conjunto_letras, rango_numeros))
print(producto_cartesiano)  # Salida: [('a', 1), ('a', 2), ('a', 3), ('b', 1), ..., ('c', 3)]
# Out:
# [('rojo', 'cuadrado'), ('rojo', 'círculo'), ('rojo', 'triángulo'), ('verde', 'cuadrado'), ('verde', 'círculo'), ('verde', 'triángulo'), ('azul', 'cuadrado'), ('azul', 'círculo'), ('azul', 'triángulo')]
# [('a', 1), ('a', 2), ('a', 3), ('b', 1), ('b', 2), ('b', 3), ('c', 1), ('c', 2), ('c', 3)]
